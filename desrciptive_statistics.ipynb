# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('coded_final.csv')

# Display descriptive statistics for the numeric columns
descriptive_stats = df.drop("RespondentID", axis=1).describe(include="all")
print(descriptive_stats)
# Out:
#        How often do you travel by plane?  \
# count                         858.000000
# mean                            1.257576
# std                             0.497456
# min                             1.000000
# 25%                             1.000000
# 50%                             1.000000
# 75%                             1.000000
# max                             5.000000
#
#        Do you ever recline your seat when you fly?  How tall are you?  \
# count                                   858.000000         858.000000
# mean                                      2.174825         171.377622
# std                                       1.382410           9.997665
# min                                       0.000000         152.400000
# 25%                                       1.000000         162.600000
# 50%                                       2.000000         170.200000
# 75%                                       3.000000         177.800000
# ...
