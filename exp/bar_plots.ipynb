# %%
import sys
sys.path.append('../src')

PATH_CODED_SCV = '../data/coded.csv'
PATH_FLYING_ETIQUETTE_CSV ='../data/flying-etiquette.csv'

from features_trans_back import features_trans_back_shortened as ftbs
from features_trans_back import question_short as qs
import matplotlib.pyplot as plt 

def plot_conditional_probs(df, condition, ftbs, qs):
    # Data for the plot
    categories = ftbs(df.keys().name)
    categories_labels = list(categories.values())

    event_qs = df.keys().name

    condition_qs = df.reset_index().columns[0]

    # Creating the plot
    plt.figure(figsize=(10, 6))
    plt.bar(categories_labels, df.loc[condition], color='skyblue')

    # Adding title and labels
    plt.title(f"Distribution: {qs(event_qs)}  | {qs(condition_qs)}  {ftbs(condition_qs, condition)}" )
    # plt.xlabel("Education Degree")
    plt.ylabel("Conditional Probabilities")

    # Rotating the x-axis labels for better readability
    plt.xticks(rotation=45)

    # Display the plot
    # plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# import seaborn as sns
from scipy.stats import chi2_contingency



df = pd.read_csv(PATH_CODED_SCV)
def calculate_conditional_probability_for_category(df, condition_column, condition_value, event_column, event_value):
    """
    Calculate conditional probability for a specific category in the condition column given the event column.

    Parameters:
    - df (pd.DataFrame): The input DataFrame.
    - condition_column (str): The column for which conditional probability is calculated.
    - condition_value: The specific category in the condition column.
    - event_column (str): The column representing the event.
    - event_value: The specific category in the event column.
    """
    condition_occurrences = df[df[condition_column] == condition_value].shape[0]
    event_and_condition_occurrences = df[(df[condition_column] == condition_value) & (df[event_column] == event_value)].shape[0]

    if condition_occurrences == 0:
        return 0  # To avoid division by zero

    conditional_probability = event_and_condition_occurrences / condition_occurrences
    return conditional_probability



def calculate_conditional_probability(df, condition_column, event_column):
    # Group by the condition column and calculate the conditional probabilities
    
    probabilities = df.groupby(condition_column)[event_column].value_counts(normalize=True).unstack()
    # print(probabilities)

    # Fill NaN values with 0 (when the condition is not present for a specific event)
    probabilities = probabilities.fillna(0)

    return probabilities



def cramers_v(df, x, y):
    confusion_matrix = pd.crosstab(df[x], df[y])

    chi2, _, _, _ = chi2_contingency(confusion_matrix)
    n = confusion_matrix.sum().sum()
    phi2 = chi2 / n
    r, k = confusion_matrix.shape
    phi2corr = max(0, phi2 - ((k-1)*(r-1))/(n-1))
    rcorr = r - ((r-1)**2)/(n-1)
    kcorr = k - ((k-1)**2)/(n-1)

    return np.sqrt(phi2corr / min((kcorr-1), (rcorr-1)))


# cramers_v_education_obligation = cramers_v(df, "Education", "Under normal circumstances, does a person who reclines their seat during a flight have any obligation to the person sitting behind them?")
# print(cramers_v_education_obligation)

# %%
def many_plots (df, feature, calculate_conditional_probability, plot_conditional_probs, ftbs, qs):
    questions = list(df.columns)[1:]
    counter = 0 
    for q in questions:
        if q == feature:
            continue
        if q == 'How tall are you?':
            continue
        conditional_prob = calculate_conditional_probability(df, feature, q)
        
        # Assuming your DataFrames are named conditional_prob and conditional_prob2

        # Plot for 'Do you ever recline your seat when you fly?'

        # plt.figure(figsize=(10, 8))  # Adjust the figure size if needed
        # plt.subplot(1, 2, 1)  # subplot for the first question
        conditional_prob.plot(kind='bar', stacked=False, width=0.7)
        plt.title(conditional_prob.columns.name)
        plt.xlabel(conditional_prob.index.name)
        plt.ylabel('Percentage')
        feature_name = ftbs(conditional_prob.columns.name)
        q_name = ftbs(conditional_prob.index.name)
        plt.xticks(range(len(q_name)), list(q_name.values()))
        plt.legend(list(feature_name.values()))

        plt.tight_layout()  # Adjust layout for better visualization
        plt.show();
        if counter==3:
            break
        counter+=1
many_plots(df, 'How often do you travel by plane?', calculate_conditional_probability, plot_conditional_probs, ftbs, qs)

# %%
df = pd.read_csv(PATH_CODED_SCV)
conditional_prob = calculate_conditional_probability(df, 'Age', list(df.columns)[2])
conditional_prob2 = calculate_conditional_probability(df, 'Age', list(df.columns)[4])
print(conditional_prob)
print(conditional_prob2)

print(conditional_prob.index.name)
# Out:
# Do you ever recline your seat when you fly?       0.0       1.0       2.0  \
# Age
# 0.0                                          0.122093  0.156977  0.122093
# 1.0                                          0.157658  0.234234  0.148649
# 2.0                                          0.213675  0.175214  0.145299
# 3.0                                          0.120930  0.255814  0.130233
#
# Do you ever recline your seat when you fly?       3.0       4.0
# Age
# 0.0                                          0.319767  0.279070
# 1.0                                          0.288288  0.171171
# 2.0                                          0.299145  0.166667
# 3.0                                          0.302326  0.190698
# Do you have any children under 18?       0.0       1.0
# Age
# 0.0                                 0.929825  0.070175
# 1.0                                 0.574661  0.425339
# 2.0                                 0.700855  0.299145
# 3.0                                 0.948357  0.051643
# Age

# %%
from features_trans_back import features_trans_back_shortened  as ftbs
from features_trans_back import question_short as qs
def many_plots (df, feature, calculate_conditional_probability, ftbs, qs):
    questions = list(df.columns)[1:]
    counter = 0 
    fig, ax = plt.subplots(4, 6, figsize=(45,35))
    ax_flat = ax.flatten()
    for q in questions:
        if q == feature:
            continue
        if q == 'How tall are you?':
            continue
        conditional_prob = calculate_conditional_probability(df, feature, q)

        ax = ax_flat[counter]
        
        conditional_prob.plot(kind='bar', stacked=False, width=0.7,ax=ax)
        print(conditional_prob)
        ax.set_title(qs(conditional_prob.columns.name))
        ax.set_xlabel(conditional_prob.index.name)
        ax.set_ylabel('Percentage')
        feature_name = ftbs(conditional_prob.columns.name)
        q_name = conditional_prob.index.name
        q_name_list = conditional_prob.index.tolist()
        
        answer_change = []
        for i in q_name_list:
            i = float(i)
            answer_change.append(ftbs(q_name, i))

        columns_list = []
        for i in conditional_prob.columns.tolist():
            i = float(i)
            columns_list.append(ftbs(conditional_prob.columns.name, i))

        ax.set_xticks(range(len(q_name_list)))
        ax.set_xticklabels(answer_change)
        ax.legend(columns_list)
        counter+=1
     
    plt.tight_layout()  # Adjust layout for better visualization
    plt.show()        
many_plots(df, 'Do you ever recline your seat when you fly?', calculate_conditional_probability, ftbs, qs)
# Out:
# How often do you travel by plane?                   1         2         3  \
# Do you ever recline your seat when you fly?
# 0.0                                          0.773723  0.160584  0.051095
# 1.0                                          0.737143  0.234286  0.022857
# 2.0                                          0.661017  0.313559  0.025424
# 3.0                                          0.700389  0.268482  0.027237
# 4.0                                          0.748538  0.198830  0.046784
#
# How often do you travel by plane?                   5         4
# Do you ever recline your seat when you fly?
# 0.0                                          0.007299  0.007299
# 1.0                                          0.005714  0.000000
# 2.0                                          0.000000  0.000000
# 3.0                                          0.003891  0.000000
# 4.0                                          0.000000  0.005848
# Do you have any children under 18?                0.0       1.0
# Do you ever recline your seat when you fly?
# 0.0                                          0.750000  0.250000
# 1.0                                          0.777143  0.222857
# 2.0                                          0.760684  0.239316
# 3.0                                          0.765625  0.234375
# 4.0                                          0.832335  0.167665
# In a row of three seats, who should get to use the two arm rests?       1.0  \
# Do you ever recline your seat when you fly?
# 0.0                                                                0.007299
# 1.0                                                                0.005714
# 2.0                                                                0.025641
# 3.0                                                                0.027344
# 4.0                                                                0.035088
#
# In a row of three seats, who should get to use the two arm rests?       2.0  \
# Do you ever recline your seat when you fly?
# 0.0                                                                0.160584
# 1.0                                                                0.125714
# 2.0                                                                0.068376
# 3.0                                                                0.097656
# 4.0                                                                0.058480
#
# In a row of three seats, who should get to use the two arm rests?       3.0  \
# Do you ever recline your seat when you fly?
# 0.0                                                                0.080292
# 1.0                                                                0.051429
# 2.0                                                                0.059829
# 3.0                                                                0.039062
# 4.0                                                                0.046784
#
# In a row of three seats, who should get to use the two arm rests?       4.0  \
# Do you ever recline your seat when you fly?
# 0.0                                                                0.598540
# 1.0                                                                0.680000
# 2.0                                                                0.683761
# 3.0                                                                0.714844
# 4.0                                                                0.719298
#
# In a row of three seats, who should get to use the two arm rests?       5.0
# Do you ever recline your seat when you fly?
# 0.0                                                                0.153285
# 1.0                                                                0.137143
# 2.0                                                                0.162393
# 3.0                                                                0.121094
# 4.0                                                                0.140351
# In a row of two seats, who should get to use the middle arm rest?       1.0  \
# Do you ever recline your seat when you fly?
# 0.0                                                                0.043796
# 1.0                                                                0.034286
# 2.0                                                                0.034188
# 3.0                                                                0.046875
# 4.0                                                                0.076023
#
# In a row of two seats, who should get to use the middle arm rest?       2.0  \
# Do you ever recline your seat when you fly?
# 0.0                                                                0.160584
# 1.0                                                                0.165714
# 2.0                                                                0.170940
# 3.0                                                                0.160156
# 4.0                                                                0.116959
#
# In a row of two seats, who should get to use the middle arm rest?       3.0  \
# Do you ever recline your seat when you fly?
# 0.0                                                                0.058394
# 1.0                                                                0.040000
# 2.0                                                                0.034188
# 3.0                                                                0.039062
# 4.0                                                                0.046784
#
# In a row of two seats, who should get to use the middle arm rest?       4.0  \
# Do you ever recline your seat when you fly?
# 0.0                                                                0.649635
# 1.0                                                                0.680000
# 2.0                                                                0.683761
# 3.0                                                                0.695312
# 4.0                                                                0.684211
#
# In a row of two seats, who should get to use the middle arm rest?       5.0
# Do you ever recline your seat when you fly?
# 0.0                                                                0.087591
# 1.0                                                                0.080000
# 2.0                                                                0.076923
# 3.0                                                                0.058594
# 4.0                                                                0.076023
# Who should have control over the window shade?       0.0       1.0
# Do you ever recline your seat when you fly?
# 0.0                                             0.481752  0.518248
# 1.0                                             0.388571  0.611429
# 2.0                                             0.435897  0.564103
# 3.0                                             0.394531  0.605469
# 4.0                                             0.438596  0.561404
# Is itrude to move to an unsold seat on a plane?       0.0       1.0       2.0
# Do you ever recline your seat when you fly?
# 0.0                                              0.882353  0.080882  0.036765
# 1.0                                              0.771429  0.194286  0.034286
# 2.0                                              0.829060  0.128205  0.042735
# 3.0                                              0.824219  0.136719  0.039062
# 4.0                                              0.742690  0.192982  0.064327
# Generally speaking, is it rude to say more than a few words tothe stranger sitting next to you on a plane?       0.0  \
# Do you ever recline your seat when you fly?
# 0.0                                                                                                         0.816176
# 1.0                                                                                                         0.794286
# 2.0                                                                                                         0.863248
# 3.0                                                                                                         0.753906
# 4.0                                                                                                         0.766082
#
# Generally speaking, is it rude to say more than a few words tothe stranger sitting next to you on a plane?       1.0  \
# Do you ever recline your seat when you fly?
# 0.0                                                                                                         0.169118
# 1.0                                                                                                         0.182857
# 2.0                                                                                                         0.094017
# 3.0                                                                                                         0.210938
# 4.0                                                                                                         0.192982
#
# Generally speaking, is it rude to say more than a few words tothe stranger sitting next to you on a plane?       2.0
# Do you ever recline your seat when you fly?
# 0.0                                                                                                         0.014706
# 1.0                                                                                                         0.022857
# 2.0                                                                                                         0.042735
# 3.0                                                                                                         0.035156
# 4.0                                                                                                         0.040936
# On a 6 hour flight from NYC to LA, how many times is it acceptable to get up if you're not in an aisle seat?       0.0  \
# Do you ever recline your seat when you fly?
# 0.0                                                                                                           0.102941
# 1.0                                                                                                           0.131429
# 2.0                                                                                                           0.136752
# 3.0                                                                                                           0.082031
# 4.0                                                                                                           0.099415
#
# On a 6 hour flight from NYC to LA, how many times is it acceptable to get up if you're not in an aisle seat?       1.0  \
# Do you ever recline your seat when you fly?
# 0.0                                                                                                           0.154412
# 1.0                                                                                                           0.142857
# 2.0                                                                                                           0.128205
# 3.0                                                                                                           0.128906
# 4.0                                                                                                           0.099415
#
# On a 6 hour flight from NYC to LA, how many times is it acceptable to get up if you're not in an aisle seat?       2.0  \
# Do you ever recline your seat when you fly?
# 0.0                                                                                                           0.338235
# 1.0                                                                                                           0.382857
# 2.0                                                                                                           0.333333
# 3.0                                                                                                           0.355469
# 4.0                                                                                                           0.309942
#
# On a 6 hour flight from NYC to LA, how many times is it acceptable to get up if you're not in an aisle seat?       3.0  \
# Do you ever recline your seat when you fly?
# 0.0                                                                                                           0.323529
# 1.0                                                                                                           0.268571
# 2.0                                                                                                           0.316239
# 3.0                                                                                                           0.339844
# 4.0                                                                                                           0.362573
#
# On a 6 hour flight from NYC to LA, how many times is it acceptable to get up if you're not in an aisle seat?       4.0  \
# Do you ever recline your seat when you fly?
# 0.0                                                                                                           0.066176
# 1.0                                                                                                           0.068571
# 2.0                                                                                                           0.076923
# 3.0                                                                                                           0.074219
# 4.0                                                                                                           0.105263
#
# On a 6 hour flight from NYC to LA, how many times is it acceptable to get up if you're not in an aisle seat?       5.0
# Do you ever recline your seat when you fly?
# 0.0                                                                                                           0.014706
# 1.0                                                                                                           0.005714
# 2.0                                                                                                           0.008547
# 3.0                                                                                                           0.019531
# 4.0                                                                                                           0.023392
# Under normal circumstances, does a person who reclines their seat during a flight have any obligation to the person sitting behind them?       0.0  \
# Do you ever recline your seat when you fly?
# 0.0                                                                                                                                       0.676471
# 1.0                                                                                                                                       0.514286
# 2.0                                                                                                                                       0.358974
# 3.0                                                                                                                                       0.246094
# 4.0                                                                                                                                       0.141176
#
# Under normal circumstances, does a person who reclines their seat during a flight have any obligation to the person sitting behind them?       1.0
# Do you ever recline your seat when you fly?
# 0.0                                                                                                                                       0.323529
# 1.0                                                                                                                                       0.485714
# 2.0                                                                                                                                       0.641026
# 3.0                                                                                                                                       0.753906
# 4.0                                                                                                                                       0.858824
# Is itrude to recline your seat on a plane?        0.0       1.0       2.0
# Do you ever recline your seat when you fly?
# 0.0                                          0.911765  0.066176  0.022059
# 1.0                                          0.828571  0.154286  0.017143
# 2.0                                          0.700855  0.299145  0.000000
# 3.0                                          0.453125  0.503906  0.042969
# 4.0                                          0.205882  0.476471  0.317647
# Given the opportunity, would you eliminate the possibility of reclining seats on planes entirely?       0.0  \
# Do you ever recline your seat when you fly?
# 0.0                                                                                                0.911765
# 1.0                                                                                                0.862857
# 2.0                                                                                                0.803419
# 3.0                                                                                                0.652344
# 4.0                                                                                                0.347059
#
# Given the opportunity, would you eliminate the possibility of reclining seats on planes entirely?       1.0
# Do you ever recline your seat when you fly?
# 0.0                                                                                                0.088235
# 1.0                                                                                                0.137143
# 2.0                                                                                                0.196581
# 3.0                                                                                                0.347656
# 4.0                                                                                                0.652941
# Is it rude to ask someone to switch seats with you in order to be closer to friends?       0.0  \
# Do you ever recline your seat when you fly?
# 0.0                                                                                   0.755556
# 1.0                                                                                   0.754286
# 2.0                                                                                   0.700855
# 3.0                                                                                   0.780392
# 4.0                                                                                   0.690476
#
# Is it rude to ask someone to switch seats with you in order to be closer to friends?       1.0  \
# Do you ever recline your seat when you fly?
# 0.0                                                                                   0.207407
# 1.0                                                                                   0.217143
# 2.0                                                                                   0.247863
# 3.0                                                                                   0.196078
# 4.0                                                                                   0.232143
#
# Is it rude to ask someone to switch seats with you in order to be closer to friends?       2.0
# Do you ever recline your seat when you fly?
# 0.0                                                                                   0.037037
# 1.0                                                                                   0.028571
# 2.0                                                                                   0.051282
# 3.0                                                                                   0.023529
# 4.0                                                                                   0.077381
# Is itrude to ask someone to switch seats with you in order to be closer to family?       0.0  \
# Do you ever recline your seat when you fly?
# 0.0                                                                                 0.844444
# 1.0                                                                                 0.840000
# 2.0                                                                                 0.777778
# 3.0                                                                                 0.866667
# 4.0                                                                                 0.785714
#
# Is itrude to ask someone to switch seats with you in order to be closer to family?       1.0  \
# Do you ever recline your seat when you fly?
# 0.0                                                                                 0.125926
# 1.0                                                                                 0.148571
# 2.0                                                                                 0.205128
# 3.0                                                                                 0.117647
# 4.0                                                                                 0.166667
#
# Is itrude to ask someone to switch seats with you in order to be closer to family?       2.0
# Do you ever recline your seat when you fly?
# 0.0                                                                                 0.029630
# 1.0                                                                                 0.011429
# 2.0                                                                                 0.017094
# 3.0                                                                                 0.015686
# 4.0                                                                                 0.047619
# Is it rude to wake a passenger up if you are trying to go to the bathroom?       0.0  \
# Do you ever recline your seat when you fly?
# 0.0                                                                         0.637037
# 1.0                                                                         0.640000
# 2.0                                                                         0.598291
# 3.0                                                                         0.611765
# 4.0                                                                         0.660714
#
# Is it rude to wake a passenger up if you are trying to go to the bathroom?       1.0  \
# Do you ever recline your seat when you fly?
# 0.0                                                                         0.325926
# 1.0                                                                         0.331429
# 2.0                                                                         0.358974
# 3.0                                                                         0.349020
# 4.0                                                                         0.285714
#
# Is it rude to wake a passenger up if you are trying to go to the bathroom?       2.0
# Do you ever recline your seat when you fly?
# 0.0                                                                         0.037037
# 1.0                                                                         0.028571
# 2.0                                                                         0.042735
# 3.0                                                                         0.039216
# 4.0                                                                         0.053571
# Is itrude to wake a passenger up if you are trying to walk around?       0.0  \
# Do you ever recline your seat when you fly?
# 0.0                                                                 0.296296
# 1.0                                                                 0.297143
# 2.0                                                                 0.247863
# 3.0                                                                 0.266667
# 4.0                                                                 0.220238
#
# Is itrude to wake a passenger up if you are trying to walk around?       1.0  \
# Do you ever recline your seat when you fly?
# 0.0                                                                 0.518519
# 1.0                                                                 0.485714
# 2.0                                                                 0.564103
# 3.0                                                                 0.525490
# 4.0                                                                 0.541667
#
# Is itrude to wake a passenger up if you are trying to walk around?       2.0
# Do you ever recline your seat when you fly?
# 0.0                                                                 0.185185
# 1.0                                                                 0.217143
# 2.0                                                                 0.188034
# 3.0                                                                 0.207843
# 4.0                                                                 0.238095
# In general, is itrude to bring a baby on a plane?       0.0       1.0  \
# Do you ever recline your seat when you fly?
# 0.0                                                0.666667  0.214815
# 1.0                                                0.714286  0.211429
# 2.0                                                0.689655  0.241379
# 3.0                                                0.713725  0.227451
# 4.0                                                0.684524  0.178571
#
# In general, is itrude to bring a baby on a plane?       2.0
# Do you ever recline your seat when you fly?
# 0.0                                                0.118519
# 1.0                                                0.074286
# 2.0                                                0.068966
# 3.0                                                0.058824
# 4.0                                                0.136905
# In general, is it rude to knowingly bring unruly children on a plane?       0.0  \
# Do you ever recline your seat when you fly?
# 0.0                                                                    0.155556
# 1.0                                                                    0.182857
# 2.0                                                                    0.241379
# 3.0                                                                    0.156863
# 4.0                                                                    0.154762
#
# In general, is it rude to knowingly bring unruly children on a plane?       1.0  \
# Do you ever recline your seat when you fly?
# 0.0                                                                    0.400000
# 1.0                                                                    0.417143
# 2.0                                                                    0.362069
# 3.0                                                                    0.431373
# 4.0                                                                    0.428571
#
# In general, is it rude to knowingly bring unruly children on a plane?       2.0
# Do you ever recline your seat when you fly?
# 0.0                                                                    0.444444
# 1.0                                                                    0.400000
# 2.0                                                                    0.396552
# 3.0                                                                    0.411765
# 4.0                                                                    0.416667
# Have you ever used personal electronics during take off or landing in violation of a flight attendant's direction?       0.0  \
# Do you ever recline your seat when you fly?
# 0.0                                                                                                                 0.792593
# 1.0                                                                                                                 0.771429
# 2.0                                                                                                                 0.827586
# 3.0                                                                                                                 0.886275
# 4.0                                                                                                                 0.886905
#
# Have you ever used personal electronics during take off or landing in violation of a flight attendant's direction?       1.0
# Do you ever recline your seat when you fly?
# 0.0                                                                                                                 0.207407
# 1.0                                                                                                                 0.228571
# 2.0                                                                                                                 0.172414
# 3.0                                                                                                                 0.113725
# 4.0                                                                                                                 0.113095
# Have you ever smoked a cigarette in an airplane bathroom when it was against the rules?       0.0  \
# Do you ever recline your seat when you fly?
# 0.0                                                                                      0.970370
# 1.0                                                                                      0.994286
# 2.0                                                                                      1.000000
# 3.0                                                                                      1.000000
# 4.0                                                                                      0.988095
#
# Have you ever smoked a cigarette in an airplane bathroom when it was against the rules?       1.0
# Do you ever recline your seat when you fly?
# 0.0                                                                                      0.029630
# 1.0                                                                                      0.005714
# 2.0                                                                                      0.000000
# 3.0                                                                                      0.000000
# 4.0                                                                                      0.011905
# Gender                                            0.0       1.0
# Do you ever recline your seat when you fly?
# 0.0                                          0.454545  0.545455
# 1.0                                          0.491429  0.508571
# 2.0                                          0.422414  0.577586
# 3.0                                          0.500000  0.500000
# 4.0                                          0.475904  0.524096
# Age                                               0.0       1.0       2.0  \
# Do you ever recline your seat when you fly?
# 0.0                                          0.159091  0.265152  0.378788
# 1.0                                          0.154286  0.297143  0.234286
# 2.0                                          0.181034  0.284483  0.293103
# 3.0                                          0.216535  0.251969  0.275591
# 4.0                                          0.289157  0.228916  0.234940
#
# Age                                               3.0
# Do you ever recline your seat when you fly?
# 0.0                                          0.196970
# 1.0                                          0.314286
# 2.0                                          0.241379
# 3.0                                          0.255906
# 4.0                                          0.246988
# Household Income                                  0.0       1.0       2.0  \
# Do you ever recline your seat when you fly?
# 0.0                                          0.069565  0.217391  0.321739
# 1.0                                          0.103226  0.154839  0.380645
# 2.0                                          0.064516  0.161290  0.387097
# 3.0                                          0.098522  0.177340  0.379310
# 4.0                                          0.090909  0.189394  0.371212
#
# Household Income                                  3.0       4.0
# Do you ever recline your seat when you fly?
# 0.0                                          0.234783  0.156522
# 1.0                                          0.232258  0.129032
# 2.0                                          0.215054  0.172043
# 3.0                                          0.172414  0.172414
# 4.0                                          0.219697  0.128788
# Education                                         0.0       1.0       2.0  \
# Do you ever recline your seat when you fly?
# 0.0                                          0.007634  0.053435  0.305344
# 1.0                                          0.005714  0.080000  0.245714
# 2.0                                          0.017544  0.026316  0.271930
# 3.0                                          0.007937  0.075397  0.250000
# 4.0                                          0.000000  0.109091  0.296970
#
# Education                                         3.0       4.0
# Do you ever recline your seat when you fly?
# 0.0                                          0.389313  0.244275
# 1.0                                          0.325714  0.342857
# 2.0                                          0.324561  0.359649
# 3.0                                          0.341270  0.325397
# 4.0                                          0.290909  0.303030
# Location (Census Region)                          0.0       1.0       2.0  \
# Do you ever recline your seat when you fly?
# 0.0                                          0.276923  0.115385  0.046154
# 1.0                                          0.252874  0.137931  0.063218
# 2.0                                          0.200000  0.139130  0.139130
# 3.0                                          0.205534  0.146245  0.051383
# 4.0                                          0.181818  0.181818  0.054545
#
# Location (Census Region)                          3.0       4.0       5.0  \
# Do you ever recline your seat when you fly?
# 0.0                                          0.053846  0.123077  0.030769
# 1.0                                          0.045977  0.155172  0.040230
# 2.0                                          0.069565  0.182609  0.017391
# 3.0                                          0.079051  0.169960  0.031621
# 4.0                                          0.066667  0.187879  0.024242
#
# Location (Census Region)                          6.0       7.0       8.0
# Do you ever recline your seat when you fly?
# 0.0                                          0.215385  0.061538  0.076923
# 1.0                                          0.132184  0.080460  0.091954
# 2.0                                          0.078261  0.069565  0.104348
# 3.0                                          0.130435  0.083004  0.102767
# 4.0                                          0.109091  0.090909  0.103030

# %%
from create_plots_feature import MakeFeaturePlots
import pandas as pd

df = pd.read_csv(PATH_CODED_SCV)
feature = 'Do you ever recline your seat when you fly?'
age_plot = MakeFeaturePlots(df, feature)
print(age_plot.list_features())
age_plot.plot_conditional_probabilities()

#df2.head()
# Out:
# ['How often do you travel by plane?', 'Do you ever recline your seat when you fly?', 'How tall are you?', 'Do you have any children under 18?', 'In a row of three seats, who should get to use the two arm rests?', 'In a row of two seats, who should get to use the middle arm rest?', 'Who should have control over the window shade?', 'Is itrude to move to an unsold seat on a plane?', 'Generally speaking, is it rude to say more than a few words tothe stranger sitting next to you on a plane?', "On a 6 hour flight from NYC to LA, how many times is it acceptable to get up if you're not in an aisle seat?", 'Under normal circumstances, does a person who reclines their seat during a flight have any obligation to the person sitting behind them?', 'Is itrude to recline your seat on a plane?', 'Given the opportunity, would you eliminate the possibility of reclining seats on planes entirely?', 'Is it rude to ask someone to switch seats with you in order to be closer to friends?', 'Is itrude to ask someone to switch seats with you in order to be closer to family?', 'Is it rude to wake a passenger up if you are trying to go to the bathroom?', 'Is itrude to wake a passenger up if you are trying to walk around?', 'In general, is itrude to bring a baby on a plane?', 'In general, is it rude to knowingly bring unruly children on a plane?', "Have you ever used personal electronics during take off or landing in violation of a flight attendant's direction?", 'Have you ever smoked a cigarette in an airplane bathroom when it was against the rules?', 'Gender', 'Age', 'Household Income', 'Education', 'Location (Census Region)']

# %%
get_feature = age_plot.list_features(0)
print(get_feature)
# Out:
# How often do you travel by plane?

# %%
df2 = pd.read_csv(PATH_FLYING_ETIQUETTE_CSV)
df2['How often do you travel by plane?'].value_counts()
# Out:
# How often do you travel by plane?
# Once a year or less      633
# Once a month or less     205
# Never                    166
# A few times per month     29
# A few times per week       4
# Every day                  3
# Name: count, dtype: int64
