# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sys

sys.path.append('../src')


PATH_CODED_CSV = '../data/coded.csv'

df = pd.read_csv(PATH_CODED_CSV)
#df = df.dropna()
#df = pd.read_csv('flying-etiquette.csv')

# %%
from features_trans_back import features_trans_back_shortened as features_trans_back
for column in df.columns:
    try:
        features_trans_back(column)
    except:
        print(column, 'failed')

# %%
import matplotlib.pyplot as plt
from matplotlib.colors import LinearSegmentedColormap

#gradient_colors = ['#ff0000', '#e63c3c', '#cd7878', '#b4b4b4', '#7878cd', '#3b3be6', '#0000ff']
gradient_colors = ['#ff0000', '#d4002a', '#aa0055', '#7f007f', '#5500aa', '#2a00d4', '#0000ff']
color_points = [(i / (len(gradient_colors) - 1), color) for i, color in enumerate(gradient_colors)]
custom_cmap = LinearSegmentedColormap.from_list('custom_colormap', color_points)

# %%
#from tueplots import bundles
#from tueplots.constants.color import *


#plt.rcParams.update(bundles.icml2022(column='full', nrows=1, ncols=2, usetex=False))

# %%
#%%capture --no-display

import numpy as np
import matplotlib.pyplot as plt

def question_map(question):
    if question == 'Under normal circumstances, does a person who reclines their seat during a flight have any obligation to the person sitting behind them?':
        return 'Is there an obligation for a passenger reclining their seat towards the person seated behind on a flight?'
    elif question == 'Have you ever used personal electronics during take off or landing in violation of a flight attendant\'s direction?':
        return "Have you ever used personal electronics during takeoff/landing against a flight attendant's instructions?"
    elif question == 'Is itrude to move to an unsold seat on a plane?':
        return 'Is it rude to move to an unsold seat on a plane?'
    elif question == 'Generally speaking, is it rude to say more than a few words to the person sitting next to you?':
        'Generally, is it rude to say more than a few words to the person sitting next to you?'
    elif question == 'On a 6 hour flight from NYC to LA, how many times is it acceptable to get up if you\'re not in an aisle seat?':
        return 'On a 6 hour flight from NYC to LA, how many times is it ok to get up if you\'re not in an aisle seat?'
    elif question == 'Is itrude to recline your seat on a plane?':
        return 'Is it rude to recline your seat on a plane?'
    elif question == 'Is itrude to ask someone to switch seats with you in order to be closer to family?':
        return 'Is it rude to ask someone to switch seats with you in order to be closer to family?'
    elif question == "Generally speaking, is it rude to say more than a few words tothe stranger sitting next to you on a plane?":
        return "Generally speaking, is it rude to say more than a few words to the stranger sitting next to you on a plane?"
    else:
        return question


def adapted_survey(axes, question, answers, category_names, index, percentage_threshold=3, text_size=10):
    """
    Adapted survey function to handle variable number of answers per question and plot on a given axis.

    Parameters:
    - axes: matplotlib.axes.Axes
        The axes array to plot the graph.
    - question: str
        The question label.
    - answers: pandas.Series
        A series of answers for the question.
    - category_names: list of str
        The category labels for this specific question.
    - index: int
        The index of the current question.
    - percentage_threshold: float, optional (default=3)
        The threshold below which percentage values will not be displayed.
    - text_size: int, optional (default=12)
        The font size for the text in the plot.
    """
    # Count the frequency of each answer and ensure the order is numerical
    answer_counts = answers.value_counts().reindex(category_names, fill_value=0).sort_index()
    total_answers = answer_counts.sum()

    # Prepare data for plotting
    data = np.array(answer_counts)
    data_cum = data.cumsum()
    
    # Get a color map with a color for NaN values
    #category_colors = plt.get_cmap('RdBu')(np.linspace(0.1, 0.9, len(category_names) -1))  # Add 1 for NaN
    category_colors = plt.get_cmap(custom_cmap)(np.linspace(0.1, 0.9, len(category_names) -1))  # Add 1 for NaN

    ax = axes[index] if len(axes) > 1 else axes
    ax.invert_xaxis()
    ax.set_ylim(-0.15, 0.15)  # Makes bars thinner
    ax.yaxis.set_visible(False)
    ax.set_xlim(0, np.max(data_cum))
    ax.tick_params(axis='x', which='both', bottom=False, top=False, labelbottom=False)

    # Hide the spines (borders)
    for spine in ax.spines.values():
        spine.set_visible(False)

    # Set and adjust the position of the title
    ax.set_title(question_map(question), loc='center', fontsize=text_size, weight='normal', y=0.87, fontdict={'family': 'Times New Roman'})  # Adjust title font size
    #ax.title.set_position([.5, 1.02])  # Further adjust title position

    for i, (colname, color) in enumerate(zip(category_names, category_colors)):
        # Filter out NaN values for the current category
        filtered_answers = answers[answers.notna()]
        
        width = filtered_answers[filtered_answers == colname].count()
        start = data_cum[i] - width

        gap_size = 2
        adjusted_width = width - gap_size

        ax.barh([question], adjusted_width, left=start+gap_size/2, height=0.5, label=colname, color=color)

        # Calculate and format the percentage
        percentage = (width / total_answers) * 100

        # Display percentage values only if they are above the threshold
        if percentage >= percentage_threshold:
            applied_text_size = text_size  # Use the default text size
            text_percentage = f'{percentage:.1f}%'  # Format the percentage
            try:
                text_answer = features_trans_back(question).get(colname, colname)  # Get the text from the dictionary
            except:
                text_answer = colname  # Answer text
            #text_answer = colname 

            # special rules for height
            if question == 'How tall are you?':
                #text_percentage = f'{percentage:.0f}%'
                text_answer = str(text_answer)[:3]
        else:
            text_percentage = ''  # Hide the percentage text
            text_answer = ''  # Hide the answer text
            applied_text_size = 0.5 * text_size  # Reduce the font size

        r, g, b, _ = color
        text_color = 'white' if r * g * b < 0.5 else 'darkgrey'

        # Position the text inside the bar with reduced gap
        text_x = start + width / 2
        text_y_percentage = -0.07  # Adjust this value to control the gap between percentage and bar
        text_y_answer = 0.07  # Adjust this value to control the gap between answer and bar
        ax.text(text_x, text_y_percentage, text_percentage, ha='center', va='center', color=text_color, fontsize=applied_text_size, weight='normal', fontdict={'family': 'Times New Roman'})  # Adjust font size
        
        # Only display answer text if percentage text is displayed
        if text_percentage:
            ax.text(text_x, text_y_answer, text_answer, ha='center', va='center', color=text_color, fontsize=applied_text_size, weight='normal', fontdict={'family': 'Times New Roman'})  # Adjust font size


selected_columns = ["How tall are you?", "Age", "Have you ever used personal electronics during take off or landing in violation of a flight attendant\'s direction?",
    'Do you have any children under 18?', 'In general, is it rude to knowingly bring unruly children on a plane?',
    "Given the opportunity, would you eliminate the possibility of reclining seats on planes entirely?"]

question_columns = [column for column in df.columns if column not in ['RespondentID']]
question_columns = selected_columns

total_questions = len(question_columns)

# Adjust the height of each subplot here
subplot_height = 0.7  # Decrease this value to reduce vertical spacing
fig, axes = plt.subplots(total_questions, 1, figsize=(10.5, total_questions * subplot_height), squeeze=False)
axes = axes.flatten()

for index, column in enumerate(question_columns):
    unique_answers = np.sort(df[column].unique())
    adapted_survey(axes, column, df[column], unique_answers, index, percentage_threshold=3.5, text_size=10)  # Adjust text size as needed

# Remove horizontal padding between subplots
plt.subplots_adjust(wspace=0)  # Set wspace to 0 to remove horizontal spacing between subplots
plt.subplots_adjust(hspace=0.6)


plt.gcf().set_dpi(600)
plt.savefig('output.pdf', format='pdf')
plt.show()

# %%
import matplotlib.pyplot as plt

# Data for plotting
x = [1, 2, 3]
y = [4, 5, 6]

# Plotting the data
plt.plot(x, y)

# Setting the title with specific font settings
plt.title('Title in Times New Roman', fontdict={'family': 'Times New Roman', 'fontsize': 16})

# Labeling the axes
plt.xlabel('X Axis Label')
plt.ylabel('Y Axis Label')

# Display the plot
plt.show()

# %%
height_counts = df['How tall are you?'].value_counts().sort_index()
print(df['How tall are you?'].mean())

# Plotting
plt.figure(figsize=(10, 6))
sns.lineplot(x=height_counts.index, y=height_counts.values)
plt.title('Frequency Distribution of Heights')
plt.xlabel('Height')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()
# Out:
# 171.37762237762237

# %%
from scipy.stats import pearsonr
import numpy as np
rho = df.dropna().corr()

# Calculate p-values
pval = df.dropna().corr(method=lambda x, y: pearsonr(x, y)[1]) - np.eye(*rho.shape)
p = pval.applymap(lambda x: ''.join(['*' for t in [.05, .01, .001] if x <= t]))

# Combine correlation values with asterisk markings
rho_with_asterisks = rho.round(2).astype(str) + p

# Define a function to determine background color intensity based on the number of asterisks
def background_color(cell):
    num_asterisks = cell.count('*')
    if num_asterisks == 0:
        return ''
    elif num_asterisks == 1:
        return 'background-color: yellow'
    elif num_asterisks == 2:
        return 'background-color: orange'
    else:
        return 'background-color: red'

# Apply background color intensity based on the number of asterisks
rho_with_asterisks = rho_with_asterisks.style.applymap(background_color)

# Display the styled correlation matrix
rho_with_asterisks
# Out:
# <style type="text/css">
# #T_3ba71_row0_col0, #T_3ba71_row0_col3, #T_3ba71_row0_col22, #T_3ba71_row1_col1, #T_3ba71_row1_col20, #T_3ba71_row1_col21, #T_3ba71_row1_col24, #T_3ba71_row2_col2, #T_3ba71_row2_col11, #T_3ba71_row2_col12, #T_3ba71_row2_col13, #T_3ba71_row2_col20, #T_3ba71_row3_col0, #T_3ba71_row3_col3, #T_3ba71_row3_col22, #T_3ba71_row4_col4, #T_3ba71_row4_col18, #T_3ba71_row4_col19, #T_3ba71_row5_col5, #T_3ba71_row5_col6, #T_3ba71_row6_col5, #T_3ba71_row6_col6, #T_3ba71_row7_col7, #T_3ba71_row8_col8, #T_3ba71_row8_col9, #T_3ba71_row8_col14, #T_3ba71_row8_col15, #T_3ba71_row9_col8, #T_3ba71_row9_col9, #T_3ba71_row9_col10, #T_3ba71_row9_col12, #T_3ba71_row9_col15, #T_3ba71_row9_col16, #T_3ba71_row9_col17, #T_3ba71_row9_col18, #T_3ba71_row10_col9, #T_3ba71_row10_col10, #T_3ba71_row10_col13, #T_3ba71_row10_col15, #T_3ba71_row10_col16, #T_3ba71_row10_col17, #T_3ba71_row11_col2, #T_3ba71_row11_col11, #T_3ba71_row11_col12, #T_3ba71_row11_col13, #T_3ba71_row11_col20, #T_3ba71_row12_col2, #T_3ba71_row12_col9, #T_3ba71_row12_col11, #T_3ba71_row12_col12, #T_3ba71_row12_col13, #T_3ba71_row12_col14, #T_3ba71_row12_col15, #T_3ba71_row12_col18, #T_3ba71_row13_col2, #T_3ba71_row13_col10, #T_3ba71_row13_col11, #T_3ba71_row13_col12, #T_3ba71_row13_col13, #T_3ba71_row14_col8, #T_3ba71_row14_col12, #T_3ba71_row14_col14, #T_3ba71_row14_col15, #T_3ba71_row14_col16, #T_3ba71_row14_col17, #T_3ba71_row15_col8, #T_3ba71_row15_col9, #T_3ba71_row15_col10, #T_3ba71_row15_col12, #T_3ba71_row15_col14, #T_3ba71_row15_col15, #T_3ba71_row15_col16, #T_3ba71_row15_col17, #T_3ba71_row15_col18, #T_3ba71_row16_col9, #T_3ba71_row16_col10, #T_3ba71_row16_col14, #T_3ba71_row16_col15, #T_3ba71_row16_col16, #T_3ba71_row16_col17, #T_3ba71_row16_col18, #T_3ba71_row16_col23, #T_3ba71_row17_col9, #T_3ba71_row17_col10, #T_3ba71_row17_col14, #T_3ba71_row17_col15, #T_3ba71_row17_col16, #T_3ba71_row17_col17, #T_3ba71_row17_col18, #T_3ba71_row17_col19, #T_3ba71_row17_col23, #T_3ba71_row18_col4, #T_3ba71_row18_col9, #T_3ba71_row18_col12, #T_3ba71_row18_col15, #T_3ba71_row18_col16, #T_3ba71_row18_col17, #T_3ba71_row18_col18, #T_3ba71_row18_col19, #T_3ba71_row18_col22, #T_3ba71_row19_col4, #T_3ba71_row19_col17, #T_3ba71_row19_col18, #T_3ba71_row19_col19, #T_3ba71_row20_col1, #T_3ba71_row20_col2, #T_3ba71_row20_col11, #T_3ba71_row20_col20, #T_3ba71_row20_col21, #T_3ba71_row20_col23, #T_3ba71_row21_col1, #T_3ba71_row21_col20, #T_3ba71_row21_col21, #T_3ba71_row22_col0, #T_3ba71_row22_col3, #T_3ba71_row22_col18, #T_3ba71_row22_col22, #T_3ba71_row23_col16, #T_3ba71_row23_col17, #T_3ba71_row23_col20, #T_3ba71_row23_col23, #T_3ba71_row23_col24, #T_3ba71_row23_col25, #T_3ba71_row24_col1, #T_3ba71_row24_col23, #T_3ba71_row24_col24, #T_3ba71_row24_col25, #T_3ba71_row25_col23, #T_3ba71_row25_col24, #T_3ba71_row25_col25, #T_3ba71_row26_col26 {
#   background-color: red;
# }
# #T_3ba71_row0_col14, #T_3ba71_row1_col3, #T_3ba71_row1_col12, #T_3ba71_row3_col1, #T_3ba71_row3_col16, #T_3ba71_row5_col7, #T_3ba71_row5_col18, #T_3ba71_row7_col5, #T_3ba71_row7_col11, #T_3ba71_row7_col15, #T_3ba71_row8_col10, #T_3ba71_row8_col12, #T_3ba71_row8_col17, #T_3ba71_row8_col18, #T_3ba71_row8_col24, #T_3ba71_row8_col25, #T_3ba71_row9_col13, #T_3ba71_row9_col14, #T_3ba71_row9_col19, #T_3ba71_row10_col8, #T_3ba71_row10_col12, #T_3ba71_row10_col14, #T_3ba71_row11_col7, #T_3ba71_row12_col1, #T_3ba71_row12_col8, #T_3ba71_row12_col10, #T_3ba71_row12_col16, #T_3ba71_row13_col9, #T_3ba71_row13_col15, #T_3ba71_row13_col23, #T_3ba71_row14_col0, #T_3ba71_row14_col9, #T_3ba71_row14_col10, #T_3ba71_row14_col18, #T_3ba71_row15_col7, #T_3ba71_row15_col13, #T_3ba71_row16_col3, #T_3ba71_row16_col12, #T_3ba71_row17_col8, #T_3ba71_row18_col5, #T_3ba71_row18_col8, #T_3ba71_row18_col14, #T_3ba71_row18_col20, #T_3ba71_row18_col23, #T_3ba71_row19_col9, #T_3ba71_row19_col21, #T_3ba71_row19_col22, #T_3ba71_row19_col23, #T_3ba71_row20_col18, #T_3ba71_row21_col19, #T_3ba71_row22_col19, #T_3ba71_row23_col13, #T_3ba71_row23_col18, #T_3ba71_row23_col19, #T_3ba71_row24_col8, #T_3ba71_row25_col8 {
#   background-color: orange;
# }
# #T_3ba71_row0_col24, #T_3ba71_row1_col11, #T_3ba71_row1_col18, #T_3ba71_row1_col22, #T_3ba71_row1_col25, #T_3ba71_row2_col9, #T_3ba71_row2_col10, #T_3ba71_row2_col23, #T_3ba71_row4_col9, #T_3ba71_row4_col23, #T_3ba71_row4_col24, #T_3ba71_row5_col8, #T_3ba71_row5_col11, #T_3ba71_row5_col23, #T_3ba71_row6_col11, #T_3ba71_row7_col18, #T_3ba71_row7_col19, #T_3ba71_row8_col5, #T_3ba71_row8_col13, #T_3ba71_row8_col19, #T_3ba71_row9_col2, #T_3ba71_row9_col4, #T_3ba71_row10_col2, #T_3ba71_row10_col19, #T_3ba71_row11_col1, #T_3ba71_row11_col5, #T_3ba71_row11_col6, #T_3ba71_row12_col19, #T_3ba71_row12_col23, #T_3ba71_row13_col8, #T_3ba71_row13_col14, #T_3ba71_row13_col20, #T_3ba71_row14_col13, #T_3ba71_row15_col19, #T_3ba71_row15_col21, #T_3ba71_row16_col22, #T_3ba71_row16_col24, #T_3ba71_row17_col26, #T_3ba71_row18_col1, #T_3ba71_row18_col7, #T_3ba71_row19_col7, #T_3ba71_row19_col8, #T_3ba71_row19_col10, #T_3ba71_row19_col12, #T_3ba71_row19_col15, #T_3ba71_row20_col13, #T_3ba71_row20_col22, #T_3ba71_row20_col26, #T_3ba71_row21_col15, #T_3ba71_row22_col1, #T_3ba71_row22_col16, #T_3ba71_row22_col20, #T_3ba71_row23_col2, #T_3ba71_row23_col4, #T_3ba71_row23_col5, #T_3ba71_row23_col12, #T_3ba71_row24_col0, #T_3ba71_row24_col4, #T_3ba71_row24_col16, #T_3ba71_row25_col1, #T_3ba71_row26_col17, #T_3ba71_row26_col20 {
#   background-color: yellow;
# }
# </style>
# <table id="T_3ba71">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3ba71_level0_col0" class="col_heading level0 col0" >RespondentID</th>
#       <th id="T_3ba71_level0_col1" class="col_heading level0 col1" >How often do you travel by plane?</th>
#       <th id="T_3ba71_level0_col2" class="col_heading level0 col2" >Do you ever recline your seat when you fly?</th>
#       <th id="T_3ba71_level0_col3" class="col_heading level0 col3" >How tall are you?</th>
#       <th id="T_3ba71_level0_col4" class="col_heading level0 col4" >Do you have any children under 18?</th>
#       <th id="T_3ba71_level0_col5" class="col_heading level0 col5" >In a row of three seats, who should get to use the two arm rests?</th>
#       <th id="T_3ba71_level0_col6" class="col_heading level0 col6" >In a row of two seats, who should get to use the middle arm rest?</th>
#       <th id="T_3ba71_level0_col7" class="col_heading level0 col7" >Who should have control over the window shade?</th>
#       <th id="T_3ba71_level0_col8" class="col_heading level0 col8" >Is itrude to move to an unsold seat on a plane?</th>
#       <th id="T_3ba71_level0_col9" class="col_heading level0 col9" >Generally speaking, is it rude to say more than a few words tothe stranger sitting next to you on a plane?</th>
#       <th id="T_3ba71_level0_col10" class="col_heading level0 col10" >On a 6 hour flight from NYC to LA, how many times is it acceptable to get up if you're not in an aisle seat?</th>
#       <th id="T_3ba71_level0_col11" class="col_heading level0 col11" >Under normal circumstances, does a person who reclines their seat during a flight have any obligation to the person sitting behind them?</th>
#       <th id="T_3ba71_level0_col12" class="col_heading level0 col12" >Is itrude to recline your seat on a plane?</th>
#       <th id="T_3ba71_level0_col13" class="col_heading level0 col13" >Given the opportunity, would you eliminate the possibility of reclining seats on planes entirely?</th>
#       <th id="T_3ba71_level0_col14" class="col_heading level0 col14" >Is it rude to ask someone to switch seats with you in order to be closer to friends?</th>
#       <th id="T_3ba71_level0_col15" class="col_heading level0 col15" >Is itrude to ask someone to switch seats with you in order to be closer to family?</th>
#       <th id="T_3ba71_level0_col16" class="col_heading level0 col16" >Is it rude to wake a passenger up if you are trying to go to the bathroom?</th>
#       <th id="T_3ba71_level0_col17" class="col_heading level0 col17" >Is itrude to wake a passenger up i

# %%
from scipy.stats import pearsonr
def calculate_pvalues(df):
    dfcols = pd.DataFrame(columns=df.columns)
    pvalues = dfcols.transpose().join(dfcols, how='outer')
    for r in df.columns:
        for c in df.columns:
            tmp = df[df[r].notnull() & df[c].notnull()]
            pvalues[r][c] = round(pearsonr(tmp[r], tmp[c])[1], 4)
    return pvalues

calculate_pvalues(df).style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# </style>
# <table id="T_1225c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1225c_level0_col0" class="col_heading level0 col0" >RespondentID</th>
#       <th id="T_1225c_level0_col1" class="col_heading level0 col1" >How often do you travel by plane?</th>
#       <th id="T_1225c_level0_col2" class="col_heading level0 col2" >Do you ever recline your seat when you fly?</th>
#       <th id="T_1225c_level0_col3" class="col_heading level0 col3" >How tall are you?</th>
#       <th id="T_1225c_level0_col4" class="col_heading level0 col4" >Do you have any children under 18?</th>
#       <th id="T_1225c_level0_col5" class="col_heading level0 col5" >In a row of three seats, who should get to use the two arm rests?</th>
#       <th id="T_1225c_level0_col6" class="col_heading level0 col6" >In a row of two seats, who should get to use the middle arm rest?</th>
#       <th id="T_1225c_level0_col7" class="col_heading level0 col7" >Who should have control over the window shade?</th>
#       <th id="T_1225c_level0_col8" class="col_heading level0 col8" >Is itrude to move to an unsold seat on a plane?</th>
#       <th id="T_1225c_level0_col9" class="col_heading level0 col9" >Generally speaking, is it rude to say more than a few words tothe stranger sitting next to you on a plane?</th>
#       <th id="T_1225c_level0_col10" class="col_heading level0 col10" >On a 6 hour flight from NYC to LA, how many times is it acceptable to get up if you're not in an aisle seat?</th>
#       <th id="T_1225c_level0_col11" class="col_heading level0 col11" >Under normal circumstances, does a person who reclines their seat during a flight have any obligation to the person sitting behind them?</th>
#       <th id="T_1225c_level0_col12" class="col_heading level0 col12" >Is itrude to recline your seat on a plane?</th>
#       <th id="T_1225c_level0_col13" class="col_heading level0 col13" >Given the opportunity, would you eliminate the possibility of reclining seats on planes entirely?</th>
#       <th id="T_1225c_level0_col14" class="col_heading level0 col14" >Is it rude to ask someone to switch seats with you in order to be closer to friends?</th>
#       <th id="T_1225c_level0_col15" class="col_heading level0 col15" >Is itrude to ask someone to switch seats with you in order to be closer to family?</th>
#       <th id="T_1225c_level0_col16" class="col_heading level0 col16" >Is it rude to wake a passenger up if you are trying to go to the bathroom?</th>
#       <th id="T_1225c_level0_col17" class="col_heading level0 col17" >Is itrude to wake a passenger up if you are trying to walk around?</th>
#       <th id="T_1225c_level0_col18" class="col_heading level0 col18" >In general, is itrude to bring a baby on a plane?</th>
#       <th id="T_1225c_level0_col19" class="col_heading level0 col19" >In general, is it rude to knowingly bring unruly children on a plane?</th>
#       <th id="T_1225c_level0_col20" class="col_heading level0 col20" >Have you ever used personal electronics during take off or landing in violation of a flight attendant's direction?</th>
#       <th id="T_1225c_level0_col21" class="col_heading level0 col21" >Have you ever smoked a cigarette in an airplane bathroom when it was against the rules?</th>
#       <th id="T_1225c_level0_col22" class="col_heading level0 col22" >Gender</th>
#       <th id="T_1225c_level0_col23" class="col_heading level0 col23" >Age</th>
#       <th id="T_1225c_level0_col24" class="col_heading level0 col24" >Household Income</th>
#       <th id="T_1225c_level0_col25" class="col_heading level0 col25" >Education</th>
#       <th id="T_1225c_level0_col26" class="col_heading level0 col26" >Location (Census Region)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1225c_level0_row0" class="row_heading level0 row0" >RespondentID</th>
#       <td id="T_1225c_row0_col0" class="data row0 col0" >0.000000</td>
#       <td id="T_1225c_row0_col1" class="data row0 col1" >0.265000</td>
#       <td id="T_1225c_row0_col2" class="data row0 col2" >0.643100</td>
#       <td id="T_1225c_row0_col3" class="data row0 col3" >0.000000</td>
#       <td id="T_1225c_row0_col4" class="data row0 col4" >0.507600</td>
#       <td id="T_1225c_row0_col5" class="data row0 col5" >0.947200</td>
#       <td id="T_1225c_row0_col6" class="data row0 col6" >0.013000</td>
#       <td id="T_1225c_row0_col7" class="data row0 col7" >0.050600</td>
#       <td id="T_1225c_row0_col8" class="data row0 col8" >0.549800</td>
#       <td id="T_1225c_row0_col9" class="data row0 col9" >0.252700</td>
#       <td id="T_1225c_row0_col10" class="data row0 col10" >0.938600</td>
#       <td id="T_1225c_row0_col11" class="data row0 col11" >0.241200</td>
#       <td id="T_1225c_row0_col12" class="data row0 col12" >0.162700</td>
#       <td id="T_1225c_row0_col13" class="data row0 col13" >0.622400</td>
#       <td id="T_1225c_row0_col14" class="data row0 col14" >0.002700</td>
#       <td id="T_1225c_row0_col15" class="data row0 col15" >0.187400</td>
#       <td id="T_1225c_row0_col16" class="data row0 col16" >0.200300</td>
#       <td id="T_1225c_row0_col17" class="data row0 col17" >0.359700</td>
#       <td id="T_1225c_row0_col18" class="data row0 col18" >0.649300</td>
#       <td id="T_1225c_row0_col19" class="data row0 col19" >0.911300</td>
#       <td id="T_1225c_row0_col20" class="data row0 col20" >0.408300</td>
#       <td id="T_1225c_row0_col21" class="data row0 col21" >0.874800</td>
#       <td id="T_1225c_row0_col22" class="data row0 col22" >0.000000</td>
#       <td id="T_1225c_row0_col23" class="data row0 col23" >0.617200</td>
#       <td id="T_1225c_row0_col24" class="data row0 col24" >0.052100</td>
#       <td id="T_1225c_row0_col25" class="data row0 col25" >0.792300</td>
#       <td id="T_1225c_row0_col26" class="data row0 col26" >0.321700</td>
#     </tr>
#     <tr>
#       <th id="T_1225c_level0_row1" class="row_heading level0 row1" >How often do you travel by plane?</th>
#       <td id="T_1225c_row1_col0" class="data row1 col0" >0.265000</td>
#       <td id="T_1225c_row1_col1" class="data row1 col1" >0.000000</td>
#       <td id="T_1225c_row1_col2" class="data row1 col2" >0.825800</td>
#       <td id="T_1225c_row1_col3" class="data row1 col3" >0.000700</td>
#       <td id="T_1225c_row1_col4" class="data row1 col4" >0.343100</td>
#       <td id="T_1225c_row1_col5" class="data row1 col5" >0.787800</td>
#       <td id="T_1225c_row1_col6" class="data row1 col6" >0.628800</td>
#       <td id="T_1225c_row1_col7" class="data row1 col7" >0.359800</td>
#       <td id="T_1225c_row1_col8" class="data row1 col8" >0.106000</td>
#       <td id="T_1225c_row1_col9" class="data row1 col9" >0.065300</td>
#       <td id="T_1225c_row1_col10" class="data row1 col10" >0.385400</td>
#       <td id="T_1225c_row1_col11" class="data row1 col11" >0.095300</td>
#       <td id="T_1225c_row1_col12" class="data row1 col12" >0.000400</td>
#       <td id="T_1225c_row1_col13" class="data row1 col13" >0.034100</td>
#       <td id="T_1225c_row1_col14" class="data row1 col14" >0.822900</td>
#       <td id="T_1225c_row1_col15" class="data row1 col15" >0.435100</td>
#       <td id="T_1225c_row1_col16" class="data row1 col16" >0.691800</td>
#       <td id="T_1225c_row1_col17" class="data row1 col17" >0.141700</td>
#       <td id="T_1225c_row1_col18" class="data row1 col18" >0.015400</td>
#       <td id="T_1225c_row1_col19" class="data row1 col19" >0.662200</td>
#       <td id="T_1225c_row1_col20" class="data row1 col20" >0.000000</td>
#       <td id="T_1225c_row1_col21" class="data row1 col21" >0.000000</td>
#       <td id="T_1225c_row1_col22" class="data row1 col22" >0.049100</td>
#       <td id="T_1225c_row1_col23" class="data row1 col23" >0.596200</td>
#       <td id="T_1225c_row1_col24" class="data row1 col24" >0.000000</td>
#       <td id="T_1225c_row1_col25" class="data row1 col25" >0.000000</td>
#       <td id="T_1225c_row1_col26" class="data row1 col26" >0.650200</td>
#     </tr>
#     <tr>
#       <th id="T_1225c_level0_row2" class="row_heading level0 row2" >Do you ever recline your seat when you fly?</th>
#       <td id="T_1225c_row2_

# %%
from sklearn.cluster import KMeans

# Filter the dataframe to include only rows with float values
filtered_df = df.select_dtypes(include=['float'])

# Drop rows with NaN values
filtered_df = filtered_df.dropna()


# Create an instance of KMeans with the desired number of clusters
kmeans = KMeans(n_clusters=3)

# Fit the data to the KMeans model
kmeans.fit(filtered_df)

# Get the cluster labels for each data point
cluster_labels = kmeans.labels_

# Add the cluster labels to the dataframe
filtered_df['Cluster'] = cluster_labels

# Print the updated dataframe
print(filtered_df)
df = filtered_df

plt.scatter(df['Household Income'], df['Education'], c=df['Cluster'])
plt.xlabel('Household Income')
plt.ylabel('Education')
plt.title('Cluster Visualization on Household Income and Education')
plt.colorbar(label='Cluster')
plt.show()
# Out:
# c:\Users\Moritz\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
#       Do you ever recline your seat when you fly?  How tall are you?  \
# 2                                             1.0              172.7
# 3                                             0.0              180.3
# 4                                             2.0              170.2
# 5                                             1.0              175.3
# 6                                             3.0              188.0
# ...                                           ...                ...
# 1028                                          4.0              162.6
# 1032                                          0.0              160.0
# 1034                                          3.0              185.4
# 1035                                          3.0              170.2
# 1039                                          3.0              190.5
#
#       Do you have any children under 18?  \
# 2                                    0.0
# 3                                    0.0
# 4                                    0.0
# 5                                    1.0
# 6                                    1.0
# ...                                  ...
# 1028                                 0.0
# 1032                                 0.0
# 1034                                 1.0
# 1035                                 0.0
# 1039                                 0.0
#
#       In a row of three seats, who should get to use the two arm rests?  \
# 2                                                   2.0
# 3                                                   4.0
# 4                                                   5.0
# 5                                                   2.0
# 6                                                   5.0
# ...                                                 ...
# 1028                                                4.0
# 1032                                                2.0
# 1034                                                5.0
# 1035                                                3.0
# 1039                                                4.0
#
#       In a row of two seats, who should get to use the middle arm rest?  \
# 2                                                   4.0
# 3                                                   4.0
# 4                                                   5.0
# 5                                                   2.0
# 6                                                   2.0
# ...                                                 ...
# 1028                                                4.0
# 1032                                                2.0
# 1034                                                3.0
# 1035                                                3.0
# 1039                                                4.0
#
#       Who should have control over the window shade?  \
# 2                                                0.0
# 3                                                1.0
# 4                                                1.0
# 5                                                0.0
# 6                                                1.0
# ...                                              ...
# 1028                                             1.0
# 1032                                             0.0
# 1034                                             1.0
# 1035                                             1.0
# 1039                                             1.0
#
#       Is itrude to move to an unsold seat on a plane?  \
# 2                                                 0.0
# 3                                                 0.0
# 4                                                 0.0
# 5                                                 1.0
# 6                                                 0.0
# ...                                               ...
# 1028                                              0.0
# 1032                                              0.0
# 1034                                              0.0
# 1035                                              0.0
# 1039                                              0.0
#
#       Generally speaking, is it rude to say more than a few words tothe stranger sitting next to you on a plane?  \
# 2                                                   0.0
# 3                                                   0.0
# 4                                                   0.0
# 5                                                   0.0
# 6                                                   1.0
# ...                                                 ...
# 1028                                                1.0
# 1032                                                0.0
# 1034                                                1.0
# 1035                                                0.0
# 1039                                                0.0
#
#       On a 6 hour flight from NYC to LA, how many times is it acceptable to get up if you're not in an aisle seat?  \
# 2                                                   2.0
# 3                                                   2.0
# 4                                                   3.0
# 5                                                   4.0
# 6                                                   3.0
# ...                                                 ...
# 1028                                                2.0
# 1032                                                4.0
# 1034                                                4.0
# 1035                                                2.0
# 1039                                                2.0
#
#       Under normal circumstances, does a person who reclines their seat during a flight have any obligation to the person sitting behind them?  \
# 2                                                   1.0
# 3                                                   0.0
# 4                                                   0.0
# 5                                                   1.0
# 6                                                   0.0
# ...                                                 ...
# 1028                                                1.0
# 1032                                                0.0
# 1034                                                0.0
# 1035                                                1.0
# 1039                                                1.0
#
#       ...  In general, is itrude to bring a baby on a plane?  \
# 2     ...                                                1.0
# 3     ...                                                1.0
# 4     ...                                                1.0
# 5     ...                                                2.0
# 6     ...                                                0.0
# ...   ...                                                ...
# 1028  ...                                                0.0
# 1032  ...                                                2.0
# 1034  ...                                                1.0
# 1035  ...                                                1.0
# 1039  ...                                                1.0
#
#       In general, is it rude to knowingly bring unruly children on a plane?  \
# 2                                                   2.0
# 3                                                   2.0
# 4                                                   2.0
# 5                                                   2.0
# 6                                                   1.0
# ...                                                 ...
# 1028                                                1.0
# 1032                                                2.0
# 1034                                                1.0
# 1035                                                2.0
# 1039                                                2.0
#
#       Have you ever used personal electronics during take off or landing in violation of a flight attendant's direction?  \
# 2                                                   0.0
# 3                                                   0.0
# 4                                                   1.0
# 5                                                   0.0
# 6                                                   0.0
# ...                                                 ...
# 1028                                                0.0
# 1032                                                1.0
# 1034                                                0.0
# 1035                                                0.0
# 1039                                                0.0
#
#       Have you ever smoked a cigarette in an airplane bathroom when it was against the rules?  \
# 2                                                   0.0
# 3                                                   0.0
# 4                                                   0.0
# 5                                                   0.0
# 6                                                   0.0
# ...                                                 ...
# 1028                                                0.0
# 1032                                                0.0
# 1034                                                0.0
# 1035                                                0.0
# 1039                                                0.0
#
#       Gender  Age  Household Income  Education  Location (Census Region)  \
# 2        0.0  1.0               3.0        3.0                       0.0
# 3        0.0  1.0               0.0        3.0                       0.0
# 4        0.0  1.0               2.0        3.0                       0.0
# 5        0.0  1.0               1.0        4.0                       1.0
# 6        0.0  1.0               4.0        2.0                       0.0
# ...      ...  ...               ...        ...                       ...
# 1028     1.0  3.0               2.0        4.0                       7.0
# 1032     1.0  1.0               4.0        1.0                       6.0
# 1034     0.0  1.0               4.0        4.0                       0.0
# 1035     0.0  1.0               0.0        2.0                       1.0
# 1039     0.0  3.0               2.0        3.0                       0.0
#
#       Cluster
# 2           2
# 3           0
# 4           2
# 5           2
# 6           0
# ...       ...
# 1028        1
# 1032        1
# 1034        0
# 1035        2
# 1039        0
#
# [687 rows x 26 columns]

# %%
df.head()
# Out:
#    Do you ever recline your seat when you fly?  How tall are you?  \
# 2                                          1.0              172.7
# 3                                          0.0              180.3
# 4                                          2.0              170.2
# 5                                          1.0              175.3
# 6                                          3.0              188.0
#
#    Do you have any children under 18?  \
# 2                                 0.0
# 3                                 0.0
# 4                                 0.0
# 5                                 1.0
# 6                                 1.0
#
#    In a row of three seats, who should get to use the two arm rests?  \
# 2                                                2.0
# 3                                                4.0
# 4                                                5.0
# 5                                                2.0
# 6                                                5.0
#
#    In a row of two seats, who should get to use the middle arm rest?  \
# 2                                                4.0
# 3                                                4.0
# 4                                                5.0
# 5                                                2.0
# 6                                                2.0
#
#    Who should have control over the window shade?  \
# 2                                             0.0
# 3                                             1.0
# 4                                             1.0
# 5                                             0.0
# 6                                             1.0
#
#    Is itrude to move to an unsold seat on a plane?  \
# 2                                              0.0
# 3                                              0.0
# 4                                              0.0
# 5                                              1.0
# 6                                              0.0
#
#    Generally speaking, is it rude to say more than a few words tothe stranger sitting next to you on a plane?  \
# 2                                                0.0
# 3                                                0.0
# 4                                                0.0
# 5                                                0.0
# 6                                                1.0
#
#    On a 6 hour flight from NYC to LA, how many times is it acceptable to get up if you're not in an aisle seat?  \
# 2                                                2.0
# 3                                                2.0
# 4                                                3.0
# 5                                                4.0
# 6                                                3.0
#
#    Under normal circumstances, does a person who reclines their seat during a flight have any obligation to the person sitting behind them?  \
# 2                                                1.0
# 3                                                0.0
# 4                                                0.0
# 5                                                1.0
# 6                                                0.0
#
#    ...  In general, is itrude to bring a baby on a plane?  \
# 2  ...                                                1.0
# 3  ...                                                1.0
# 4  ...                                                1.0
# 5  ...                                                2.0
# 6  ...                                                0.0
#
#    In general, is it rude to knowingly bring unruly children on a plane?  \
# 2                                                2.0
# 3                                                2.0
# 4                                                2.0
# 5                                                2.0
# 6                                                1.0
#
#    Have you ever used personal electronics during take off or landing in violation of a flight attendant's direction?  \
# 2                                                0.0
# 3                                                0.0
# 4                                                1.0
# 5                                                0.0
# 6                                                0.0
#
#    Have you ever smoked a cigarette in an airplane bathroom when it was against the rules?  \
# 2                                                0.0
# 3                                                0.0
# 4                                                0.0
# 5                                                0.0
# 6                                                0.0
#
#    Gender  Age  Household Income  Education  Location (Census Region)  Cluster
# 2     0.0  1.0               3.0        3.0                       0.0        2
# 3     0.0  1.0               0.0        3.0                       0.0        0
# 4     0.0  1.0               2.0        3.0                       0.0        2
# 5     0.0  1.0               1.0        4.0                       1.0        2
# 6     0.0  1.0               4.0        2.0                       0.0        0
#
# [5 rows x 26 columns]

# %%
import pandas as pd

# Assuming 'df' is your DataFrame

# Select two categorical variables
var1 = 'Do you ever recline your seat when you fly?'
var2 = 'Who should have control over the window shade?'

# Create contingency table
contingency_table = pd.crosstab(df[var1], df[var2])

# Output the table
print(contingency_table)
# Out:
# Who should have control over the window shade?  0.0  1.0
# Do you ever recline your seat when you fly?
# 0.0                                              57   55
# 1.0                                              62   92
# 2.0                                              40   53
# 3.0                                              77  122
# 4.0                                              60   69

# %%
import pandas as pd
from scipy.stats import chi2_contingency
df = pd.read_csv(PATH_CODED_CSV)

# Create a contingency table
contingency_table = pd.crosstab(df['Household Income'], df['How often do you travel by plane?'])

print(contingency_table)
# Perform the chi-square test
chi2, p, dof, expected = chi2_contingency(contingency_table)

# Output the results
print(f"Chi-Square Statistic: {chi2}")
print(f"P-value: {p}")
# Out:
# How often do you travel by plane?   0    1   2   3  4  5
# Household Income
# 0.0                                37   55   5   1  0  1
# 1.0                                34  105  18   1  0  1
# 2.0                                36  191  62   4  1  0
# 3.0                                12  103  36   8  0  0
# 4.0                                 9   52  41  12  1  0
# Chi-Square Statistic: 122.93576796429913
# P-value: 8.134009470066406e-17
