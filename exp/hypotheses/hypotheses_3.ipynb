# %%
import sys
sys.path.append('../../src')

from create_plots_feature import MakeFeaturePlots

# %% [markdown]
# ### Hypotheses 3: Flying Frequency and Seat Reclining
#
# Flying Frequency: How often do you travel by plane? \
# Seat Reclining: Do you ever recline your seat when you fly?

# %%
import pandas as pd
from matplotlib import pyplot as plt
from tueplots.constants.color import rgb

PATH_CODED_CSV = '../../data/coded.csv'

event = "How often do you travel by plane?"
condition = 'Do you ever recline your seat when you fly?'

df  = pd.read_csv(PATH_CODED_CSV)

plotter = MakeFeaturePlots(df, condition)

plotter.one_plot(event, color=[rgb.tue_red, rgb.tue_green], save_plot='hypo_3.pdf')
# Out:
# findfont: Generic family 'serif' not found because none of the following families were found: Times
# findfont: Generic family 'serif' not found because none of the following families were found: Times
# findfont: Generic family 'serif' not found because none of the following families were found: Times
# findfont: Generic family 'serif' not found because none of the following families were found: Times
# findfont: Generic family 'serif' not found because none of the following families were found: Times
# findfont: Generic family 'serif' not found because none of the following families were found: Times
# findfont: Generic family 'serif' not found because none of the following families were found: Times
# findfont: Generic family 'serif' not found because none of the following families were found: Times
# findfont: Generic family 'serif' not found because none of the following families were found: Times
# ...
